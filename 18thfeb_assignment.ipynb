# %%
# Q-1
"""An API (Application Programming Interface) is a set of rules, protocols, and tools that allows different software applications to
communicate with each other. APIs define how software components should interact,
making it easier for developers to integrate their own applications with external services, databases, or platforms without needing to understand the inner workings of those services
    
real life ex: a weather app in our mobile System
here app do not gather data but they extract it fom various platform thriugh the use of api. """


#Q-2
""" ----------> advantage: 
1 scalability
2 efficiency
3 innovations
4. access to third party services


----------> disadvantages:
1. risks of data / security risks
2. dependency
3. performance issue
4. cost 
"""

#Q-3
"""A Web API is a type of Application Programming Interface (API) that allows developers to access web-based services.
   It is a system-to-system interaction that allows one system to access information from another system


    api: The API processes the request and returns the requested data in the form of a response, usually in JSON or XML format

   web api: A web API (Application Programming Interface) is a framework that allows users to create and develop HTTP-based RESTFUL services.
   Web APIs can be accessed over the web using the HTTP protocol
"""



#Q-4
""" REST and SOAP are both architectural styles and API technologies.
 REST stands for representational state transfer, and SOAP stands for simple object access protocol.

 Scalability: REST is more scalable than SOAP because it allows for stateless and layered architecture.
Bandwidth: REST requires less bandwidth than SOAP.
Security: SOAP has tighter security than REST, including WS-Security and SSL support.
Data format: REST supports many data formats, including plain text, HTML, XML, and JSON. SOAP only uses XML.
Caching: REST calls can be cached, but SOAP-based calls cannot.
Protocol vs. architecture: SOAP is a protocol, while REST is an architectural style.
Flexibility: REST is more flexible than SOAP.
"""

#Q-5
"""
calability: REST is more scalable than SOAP because it allows for stateless and layered architecture.
Bandwidth: REST requires less bandwidth than SOAP.
Security: SOAP has tighter security than REST, including WS-Security and SSL support.
Data format: REST supports many data formats, including plain text, HTML, XML, and JSON. SOAP only uses XML.
Caching: REST calls can be cached, but SOAP-based calls cannot.
Protocol vs. architecture: SOAP is a protocol, while REST is an architectural style.
Flexibility: REST is more flexible than SOAP.
"""
